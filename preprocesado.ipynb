# %%
import pandas as pd


#--------------------Llenar datos vacíos
#Llena los datos nulos con ffill para que los datos sean más coherente, y con cero
#en caso de quedar algún nulo
data_social = data_social.fillna(method='ffill').fillna(0)
total_nulos = data_social.isnull().sum().sum()
porcentaje_nulos_total = (total_nulos / total_celdas) * 100
print(f"Porcentaje de datos nulos o vacíos: {porcentaje_nulos_total:.2f}%")
# Out:
# sample_data
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-f2b77fe8497a> in <cell line: 0>()
#       4
#       5 # Cargar todas las variables
# ----> 6 with open("entorno.pkl", "rb") as f:
#       7     dill.load_session(f)
#       8 #--------------------Llenar datos vacíos
#
# FileNotFoundError: [Errno 2] No such file or directory: 'entorno.pkl'
